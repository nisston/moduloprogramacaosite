# %% [markdown]
# # Primeiros Passos na Programação
#
# Aqui vamos apresentar todos os tópicos discutidos em sala de aula pelo professor, com uma ou duas células com exemplos práticos da aplicação do comando ou recurso. A seguir a lista de tópicos trabalhados:
#
# * Instalando e usando o interpretador
# * Entrada de dados
# * Saída de dados
# * Tipos de dados
# * Identificadores e variáveis
# * Operadores aritméticos e expressões
#
#
# Para maiores informações segue um pequeno tutorial: [Tutorial de Python](https://docs.python.org/pt-br/3/tutorial/)

# %% [markdown]
# # Executando com o interpretador
#
# * Shift + Enter
# * Ctrl + Enter

# %%
# Executando um comando
print('Olá Mundo')
# Out:
# Olá Mundo

# %%
# Executando um conjunto de comandos
valor=6
for i in range(1,11):
  print(i,' * ',valor,'=',i*valor)
# Out:
# 1  *  6 = 6
# 2  *  6 = 12
# 3  *  6 = 18
# 4  *  6 = 24
# 5  *  6 = 30
# 6  *  6 = 36
# 7  *  6 = 42
# 8  *  6 = 48
# 9  *  6 = 54
# 10  *  6 = 60

# %%
# Executando com erro de syntaxe
valor=6
for i in range(1,11,2):
  print(i,' * ',valor,'=',i*valor)
# Out:
# 1  *  6 = 6
# 3  *  6 = 18
# 5  *  6 = 30
# 7  *  6 = 42
# 9  *  6 = 54

# %% [markdown]
# # Entrada de dados

# %%
input('Informe um valor.: ')
# Out:
# Informe um valor.: 5
# '5'

# %%
nome = input('Informe um nome.: ')
print('O nome digitado foi..: ',nome)
# Out:
# Informe um nome.: Aluno
# O nome digitado foi..:  Aluno

# %% [markdown]
# # Saída de dados

# %%
valor = 200
print('Informe um valor')
print(valor)
print('O valor informado foi', valor)
# Out:
# Informe um valor
# 200
# O valor informado foi 200

# %%
valor = 200
print('O valor informado foi', valor)
# Out:
# O valor informado foi 200

# %%
valor = 200
print('O valor informado foi\n', valor)
# Out:
# O valor informado foi
#  200

# %% [markdown]
# # Tipos de dados

# %%
A = 23
B = 'Universidade'
C = 2.5
D = True

# %%
print(A)
print(B)
print(C)
print(D)
# Out:
# 23
# Universidade
# 2.5
# True

# %%
print(type(A))
print(type(B))
print(type(C))
print(type(D))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# # Identificadores e variáveis

# %%
# Identificadores de variáveis
nome = "João"
idade = 25
altura = 1.75
estudante = True

# Imprimindo os valores
print(nome)
print(idade)
print(altura)
print(estudante)
# Out:
# João
# 25
# 1.75
# True

# %%
nome_completo = input('Informe o seu nome completo: ')
endereco_de_atendimento = input('Qual o endereço de entrega')
# Out:
# Informe o seu nome completo: Alunos
# Qual o endereço de entregaRua Manoel Carlos

# %%
# Identificador inválido
1nome = 'Paulo'
# Out:
#   File "<ipython-input-14-9901632175ae>", line 2
#     1nome = 'Paulo'
#     ^
# SyntaxError: invalid decimal literal

# %%
# Identificador inválido
nome completto = 'Paulo Costa da Silva'
# Out:
#   File "<ipython-input-15-d65cf8b1801e>", line 2
#     nome completto = 'Paulo Costa da Silva'
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Operadores aritméticos e expressões

# %%
# Valores
valor1 = 10
valor2 = 20

# Variáveis
x = valor1
y = valor2

# Operadores
soma = x + y
subtracao = x - y
produto = x * y
divisao = y / x
modulo = y % x

# Expressão completa
# Combinação de valores, variáveis e operadores
expressao = (soma * produto) / (divisao + modulo)

# Imprimindo os resultados
print("Valor de x:", x)
print("Valor de y:", y)
print("Soma:", soma)
print("Produto:", produto)
print("Divisão:", divisao)
print("Módulo:", modulo)
print("Resultado da expressão:", expressao)
# Out:
# Valor de x: 10
# Valor de y: 20
# Soma: 30
# Produto: 200
# Divisão: 2.0
# Módulo: 0
# Resultado da expressão: 3000.0

# %%
print(20+32)
print(20-12)
print(20*32)
print(20/2)
print(20**2)
# Out:
# 52
# 8
# 640
# 10.0
# 400

# %%
# Atribuindo valor a uma variável
X = 7
Y = 6
Z = X + Y
print(Z)
# Out:
# 13

# %%
# Os parênteses
print(2 * (3 - 1))
print(2 * 3 - 1)
# Out:
# 4
# 5

# %%
# Exponenciação
print(2 ** 1 + 1)
print(3 * 1 ** 3)
# Out:
# 3
# 3

# %%
# Multiplicação e Divisão
# Adição e subtração
print(2 * 3 - 1)
print(6 + 4 / 2)
# Out:
# 5
# 8.0
